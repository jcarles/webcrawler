# %%
import pandas as pd
from datetime import datetime

df = pd.read_csv("./ufo.csv")
df
#for i in df['Date / Time']:
#    df['date'] = datetime.strptime(i[0:8].strip(), '%m/%d/%y')
df_sort= df.sort_values(by='Date / Time', ascending=True)
pd.options.display.max_rows=2000
df_sort[:100]
# Out:
#                  Date / Time  \
# 33558                     --
# 85185         --/--/83 13:00
# 50921           -25-94 05:00
# 30992           0/8/91 05:10
# 8726          00/00/00 15:00
# 8717        00/00/1981 21:05
# 109385      00/00/1994 15:00
# 44589         00/00/62 21:00
# 64349         00/00/62 22:00
# 56379         00/00/65 20:00
# 109386        00/00/82 14:00
# 8710          00/00/99 22:30
# 85188                  00:00
# 70155                  00:00
# 8742                   00:30
# 53054         01/--/00 21:00
# 112861        01/15/70 22:30
# 8741                   01:00
# 99103                  01:00
# 58566                  01:00
# 109389                 01:00
# 30993                  01:00
# 99104                  01:00
# 12016                  01:10
# 50922                  01:40
# 80372                  02:00
# 8739                   02:00
# 8737                   02:15
# 8736                   02:30
# 55426                  02:45
# 58565                  03:00
# ...
