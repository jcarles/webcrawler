# %%
import pandas as pd
df = pd.read_csv("./ufo.csv")
df
# Out:
#            Date / Time                                   City State  \
# 0        9/30/19 01:00                          kerman , Iran   NaN
# 1        9/29/19 19:35                       Tijuana (Mexico)   NaN
# 2        9/29/19 16:50                            Santo André   NaN
# 3        9/28/19 19:07                                    NaN   NaN
# 4        9/28/19 14:00                            Bonne Terre   NaN
# ...                ...                                    ...   ...
# 122565    2/5/05 09:15                    Whitehorse (Canada)    YT
# 122566  10/21/03 03:00       Yukon Territory (rural) (Canada)    YT
# 122567   6/12/02 22:00             Port Macquarie (Australia)    YT
# 122568   9/23/00 20:18  Fort Nelson (80 miles NW of) (Canada)    YT
# 122569    9/1/93 03:00               Yukon Territory (Canada)    YT
#
#             Shape      Duration  \
# 0           Flash           NaN
# 1           Other     5 minutes
# 2           Light      1 minute
# ...
